# %%
import pandas as pd 

data = pd.read_csv("donnees/50_Startups.csv")

data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from mpl_toolkits.mplot3d import Axes3D

data = pd.read_csv("donnees/50_Startups.csv")

# Prepare the data
X = data[["R&D Spend","Administration","Marketing Spend"]]
y = data["Profit"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0) 

X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, test_size=0.5)

print(X.shape, y.shape,'\n')

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)

data.plot(kind='scatter', x="R&D Spend", y="Profit")
plt.show()

# Select a linear model
model = sklearn.linear_model.LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make a prediction for new startup
X_new = [[75000,100000,300000]]  # Cyprus' GDP per capita
print(model.predict(X_new)) # outputs [[ 5.96242338]]
# Out:
# (50, 3) (50,)
#
# (30, 3) (30,)
# (10, 3) (10,)
# (10, 3) (10,)
# [114892.85528438]

# %%
from sklearn.metrics import mean_absolute_error
y_true = y_valid
y_pred = model.predict(X_valid)
print(model.predict(X_valid))
print(mean_absolute_error(y_true, y_pred))

print(X_valid)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_valid["Administration"],X_valid["R&D Spend"], y_pred, marker="x")
ax.scatter(X_valid["Administration"],X_valid["R&D Spend"], y_true, marker="x")
plt.show()
plt.close()
# Out:
# [171672.55426751  96404.92149824  98239.82399655 103788.39105804
#  151560.52519393  65868.5985353   45792.41695937 135016.93713064
#  161845.63286621  43860.46305344]
# 8595.798631212205
#     R&D Spend  Administration  Marketing Spend
# 4   142107.34        91391.77        366168.42
# 33   55493.95       103057.49        214634.81
# 31   61136.38       152701.92         88218.23
# 28   66051.52       182645.56        118148.20
# 14  119943.24       156547.42        256512.92
# 38   20229.59        65947.93        185265.10
# 45    1000.23       124153.04          1903.93
# 10  101913.08       110594.11        229160.95
# 7   130298.13       145530.06        323876.68
# 48     542.05        51743.15             0.00

# %%
from sklearn.metrics import r2_score
y_true = y_valid
y_pred = model.predict(X_valid)
r2_score(y_true, y_pred)
# Out:
# 0.9712444311904416

# %%
from sklearn.metrics import r2_score
y_true = y_test
y_pred = model.predict(X_test)
r2_score(y_true, y_pred)
# Out:
# 0.8030357410263096
