# %% [markdown]
# # Python et SQL : faire des requêtes

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+pymysql://rafik:simplon@localhost/sakila")
# https://docs.sqlalchemy.org/en/14/core/engines.html

# %%
actor = pd.read_sql_query("select * from actor;", engine)

# %%
actor
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
prenom = 'Rafik'
nom = 'LACHAAL'
engine.execute('insert into actor (first_name, last_name) values ("%s", "%s");' %(prenom, nom))

# %%
actor = pd.read_sql_query("select * from actor", engine)

# %%
actor
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
# 200       203      Rafik       LACHAAL 2021-05-25 14:54:17
#
# [201 rows x 4 columns]

# %%
engine.execute("delete from actor where first_name='Rafik'")

# %%
pd.read_sql_query("select * from actor", engine)
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
nom = input("Veuillez entrer le nom de l'acteur : ")
prenom = input("Veuillez entrer le prenom de l'acteur : ")
engine.execute('insert into actor (first_name, last_name) values ("%s", "%s");' %(prenom, nom))
# Out:
# Veuillez entrer le nom de l'acteur : LACHAAL
# Veuillez entrer le prenom de l'acteur : Rafik

# %%
pd.read_sql_query("select * from actor", engine)
# Out:
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
# 200       204      Rafik       LACHAAL 2021-05-25 14:57:47
#
# [201 rows x 4 columns]

# %%
prenom = input("Veuillez entrer le prenom de l'acteur que vous souhaitez supprimer: ")
engine.execute("delete from actor where first_name='%s';" %(prenom))
pd.read_sql_query("select * from actor", engine)
# Out:
# Veuillez entrer le prenom de l'acteur que vous souhaitez supprimer: Rafik
#      actor_id first_name     last_name         last_update
# 0           1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1           2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2           3         ED         CHASE 2006-02-15 04:34:33
# 3           4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4           5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..        ...        ...           ...                 ...
# 195       196       BELA        WALKEN 2006-02-15 04:34:33
# 196       197      REESE          WEST 2006-02-15 04:34:33
# 197       198       MARY        KEITEL 2006-02-15 04:34:33
# 198       199      JULIA       FAWCETT 2006-02-15 04:34:33
# 199       200      THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Suite à un partenariat entre une compagnie d'assurance et le videos club, 3000 nouveaux clients doivent être ajouter à la base de données. Toute les données necessaire pour ajouter ces nouveaux clients sont contenues dans un fichier Excel

# %% [markdown]
# On va donc utiliser la méthode pd.read_excel()

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+pymysql://rafik:simplon@localhost/sakila")
# https://docs.sqlalchemy.org/en/14/core/engines.html

customers_3000 = pd.read_excel('Jeux_de_donnees\\Companie_des_3000.xlsx')
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
customers_3000
# Out:
#      NameSet  Number  Gender Title GivenName MiddleInitial      Surname  \
# 0     French       1    male   Mr.    Victor             A    Boisclair
# 1     French       2  female   Ms.   Lucille             B      Pirouet
# 2     French       3    male   Mr.    Marcel             M       Robert
# 3     French       4    male   Mr.     Tyson             V     Gosselin
# 4     French       5  female   Ms.   Fanette             D     Monrency
# ...      ...     ...     ...   ...       ...           ...          ...
# 2995  French    2996    male   Mr.    Joseph             A  Sanschagrin
# 2996  French    2997  female  Mrs.  Lorraine             Z    Veronneau
# 2997  French    2998    male   Mr.    Honoré             R    Blanchard
# 2998  French    2999    male   Mr.      Paul             M     Beaulieu
# 2999  French    3000  female   Ms.  Adélaïde             L    Des Meaux
#
#                  StreetAddress                    City State  ... Country  \
# ...

# %% [markdown]
# Les clients étant tous français leurs villes n'aparaissent pas dans la tables city de la base Sakila qui ne contient que des villes Américaine. Il va donc falloir les ajouter.

# %% [markdown]
# Pour ce faire on va créer un DataFrame à l'image de la table city contenant nos nouvelle villes :
# - On va dabord récupérer le nom des colonnes de la table.
# - Les villes étant toute Française, on va récupérer l'id de la France pour remplir la colonne country_id
# - Puis on va remplir la colonne last_update avec la date du jour

# %%
column_city = pd.read_sql_query("select * from city limit 1", engine).columns
column_city
# Out:
# Index(['city_id', 'city', 'country_id', 'last_update'], dtype='object')

# %%
city = pd.DataFrame(columns = column_city)
city['city'] = customers_3000['City']
city.drop_duplicates(inplace=True)

# %%
city
# Out:
#      city_id                   city country_id last_update
# 0        NaN                BAGNEUX        NaN         NaN
# 1        NaN                  TOURS        NaN         NaN
# 2        NaN  PIERREFITTE-SUR-SEINE        NaN         NaN
# 3        NaN   LE PERREUX-SUR-MARNE        NaN         NaN
# 4        NaN              MARSEILLE        NaN         NaN
# ...      ...                    ...        ...         ...
# 2150     NaN             SAINT-MALO        NaN         NaN
# 2262     NaN         NOISY-LE-GRAND        NaN         NaN
# 2264     NaN       LA ROCHE-SUR-YON        NaN         NaN
# 2448     NaN       CORBEIL-ESSONNES        NaN         NaN
# 2622     NaN             VILLEPINTE        NaN         NaN
#
# [451 rows x 4 columns]

# %%
france_id = pd.read_sql_query("select country_id from country where country = 'France'", engine).values

# %%
france_id
# Out:
# array([[34]], dtype=int64)

# %%
city['country_id'] = france_id[0,0]
city
# Out:
#      city_id                    city  country_id last_update
# 0        NaN                 BAGNEUX          34         NaN
# 1        NaN                   TOURS          34         NaN
# 2        NaN   PIERREFITTE-SUR-SEINE          34         NaN
# 3        NaN    LE PERREUX-SUR-MARNE          34         NaN
# 4        NaN               MARSEILLE          34         NaN
# ...      ...                     ...         ...         ...
# 2995     NaN             ROMAINVILLE          34         NaN
# 2996     NaN                    LYON          34         NaN
# 2997     NaN          JOUÉ-LÈS-TOURS          34         NaN
# 2998     NaN                HAGUENAU          34         NaN
# 2999     NaN  VILLEFRANCHE-SUR-SAÔNE          34         NaN
#
# [3000 rows x 4 columns]

# %%
city['last_update']=pd.Timestamp.now()
city
# Out:
#      city_id                    city  country_id                last_update
# 0        NaN                 BAGNEUX          34 2021-05-26 11:46:22.476781
# 1        NaN                   TOURS          34 2021-05-26 11:46:22.476781
# 2        NaN   PIERREFITTE-SUR-SEINE          34 2021-05-26 11:46:22.476781
# 3        NaN    LE PERREUX-SUR-MARNE          34 2021-05-26 11:46:22.476781
# 4        NaN               MARSEILLE          34 2021-05-26 11:46:22.476781
# ...      ...                     ...         ...                        ...
# 2995     NaN             ROMAINVILLE          34 2021-05-26 11:46:22.476781
# 2996     NaN                    LYON          34 2021-05-26 11:46:22.476781
# 2997     NaN          JOUÉ-LÈS-TOURS          34 2021-05-26 11:46:22.476781
# 2998     NaN                HAGUENAU          34 2021-05-26 11:46:22.476781
# 2999     NaN  VILLEFRANCHE-SUR-SAÔNE          34 2021-05-26 11:46:22.476781
#
# [3000 rows x 4 columns]

# %%
city.to_sql('city', if_exists='append', con=engine, index=False)
