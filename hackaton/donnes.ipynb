# %%
import pandas as pd
data = pd.read_csv("datatourisme.reg-pac.20210830.csv")

# %%
data.columns
data["Classements_du_POI"].value_counts()
# Out:
# Engagé à respecter les protocoles sanitaires officiels Covid-19#DATAtourisme labels                                                                                                  800
# Accueil Vélo#France Vélo Tourisme                                                                                                                                                    647
# 2 étoiles#Classement officiel des hébergements touristiques                                                                                                                          456
# Accueil Vélo#France Vélo Tourisme|Engagé à respecter les protocoles sanitaires officiels Covid-19#DATAtourisme labels                                                                 49
# 2 étoiles#Classement officiel des hébergements touristiques|Engagé à respecter les protocoles sanitaires officiels Covid-19#DATAtourisme labels                                       45
# ...

# %%
data[data["Code_postal_et_commune"]=="06400#Cannes"]
# Out:
#                              Nom_du_POI  \
# 362     Musée des Explorations du Monde
# 649               Hôtel Montaigne & Spa
# 1681    Hôtel La Bastide de l'Oliveraie
# 1731           Hôtel Ibis Cannes Centre
# 2142       Office de Tourisme de Cannes
# ...                                 ...
# 20343    Campus International de Cannes
# 20497  Casino Barrière Cannes Croisette
# 20556       Restaurant Plage La Mandala
# 20757    Radisson Blu 1835 Hotel Cannes
# 21231               Hôtel Les Tourrades
#
#                                        Categories_de_POI   Latitude  \
# 362    http://schema.org/Museum|https://www.datatouri...  43.560315
# 649    https://www.datatourisme.gouv.fr/ontology/core...  43.554934
# 1681   https://www.datatourisme.gouv.fr/ontology/core...  43.557121
# 1731   https://www.datatourisme.gouv.fr/ontology/core...  43.552883
# 2142   https://www.datatourisme.gouv.fr/ontology/core...  43.551386
# ...
