# %% [markdown]
# ## Introduction
#
# - Lire 'unrate.csv' dans un dataframe et assigner ce résultat à la variable unrate
# - Utiliser la fonction pandas.to_datetime () pour convertir la colonne 'DATE' en valeurs
# - Afficher les 12 premières valeurs de unrate correspondant à une année entière.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

unrate = pd.read_csv("jeux_donnees/unrate.csv")
unrate
# Out:
#            DATE  UNRATE
# 0    1948-01-01     3.4
# 1    1948-02-01     3.8
# 2    1948-03-01     4.0
# 3    1948-04-01     3.9
# 4    1948-05-01     3.5
# ..          ...     ...
# 836  2017-09-01     4.2
# 837  2017-10-01     4.1
# 838  2017-11-01     4.1
# 839  2017-12-01     4.1
# 840  2018-01-01     4.1
#
# [841 rows x 2 columns]

# %%
unrate["DATE"] = pd.to_datetime(unrate["DATE"])
unrate.head(12)
# Out:
#          DATE  UNRATE
# 0  1948-01-01     3.4
# 1  1948-02-01     3.8
# 2  1948-03-01     4.0
# 3  1948-04-01     3.9
# 4  1948-05-01     3.5
# 5  1948-06-01     3.6
# 6  1948-07-01     3.6
# 7  1948-08-01     3.9
# 8  1948-09-01     3.8
# 9  1948-10-01     3.7
# 10 1948-11-01     3.8
# 11 1948-12-01     4.0

# %% [markdown]
# ## Premier graphiques
#
# - Générer un graphique linéaire permettant de visualiser les taux de chômage de 1948:
#     - Prendre pour x les 12 premières valeurs de la colonne 'DATE'
#     - Prendre pour y les 12 premières valeurs de la colonne 'UNRATE'
# - Afficher le graphique.
#
# ## Créer une rotation sur les données de l'axe x
#
# - Générer le même graphique linéaire pour visualiser le taux de chômage en 1948:
#     - prendre pour x les 12 premières valeurs de la colonne 'DATE'
#     - prendre pour y les 12 premières valeurs de la colonne 'UNRATE'
# - Utiliser la fonction pyplot.xticks () pour créer une roration de 90
# degrés.
# - Afficher le graphique.
#
# ## Ajouter les intitulés des axes et un titre à notre graphique
# - Générer le même graphique que précédemment en ajoutant les intitulés des axes x et y ainsi que le titre.
# - Définir le nom de l'axe x par "Mois".
# - Définir le nom de l'axe y par "Taux de chômage (%)".
# - Définir le titre par "Evolution du taux de chômage en 1948 aux USA".
# - Afficher le graphique.

# %%
plt.figure(figsize=(9,5), facecolor="white")

plt.plot(unrate["DATE"][:12], unrate["UNRATE"][:12], marker="o")

plt.title("Evolution du taux de chômage en 1948 aux USA")
plt.xlabel("Mois")
plt.ylabel("Taux de chômage (%)")
plt.xticks(rotation=90)

plt.show()
plt.close()

# %% [markdown]
# ## Position des graphiques
#
# Créer 6 graphiques vides sur 2 lignes et 3 colonnes.
# Maintenant Créer 2 courbes linéaires dans une grille 2 lignes 1 colonne:
# - Dans le sous graphique du haut, tracer les données de 1948.
#     - prendre pour l'axe x les 12 premières valeurs de la colonne 'DATE'
#     - prendre pour l'axe y les 12 premières valeurs de la colonne 'UNRATE'
# - Dans le sous graphique du bas, tracer les données de 1949.
#     - prendre pour l'axe x les valeurs d'index 12 à 24 de la colonne 'DATE' (les 12 valeurs suivantes du dataframe)
#     - prendre pour l'axe y les valeurs d'index 12 à 24 de la colonne 'UNRATE'
# - Afficher les 2 graphiques.

# %%
fig, axs = plt.subplots(2,3,figsize=(16,12), facecolor="white")
plt.show()
plt.close()

# %%
fig, axs = plt.subplots(2,1,figsize=(8,15),facecolor="white")

axs[0].plot(unrate["DATE"][:12], unrate["UNRATE"][:12], marker="o")
axs[0].set_title("Taux de chômage en 1948")
axs[0].set_xlabel("Mois")
axs[0].set_ylabel("Taux de chômage (%)")

axs[1].plot(unrate["DATE"][12:24], unrate["UNRATE"][12:24], marker="o")
axs[1].set_title("Taux de chômage en 1949")
axs[1].set_xlabel("Mois")
axs[1].set_ylabel("Taux de chômage (%)")

plt.show()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %% [markdown]
# ## Superposition de courbes
#
# - Créer une colonne 'MONTH' à partir de la colonne 'DATE'
# - Définir la zone d'affichage à 6 pouces de large et 3 pouces de haut.
# - Générer 2 courbes dans un seul graphique en utilisant la colonne 'MONTH' pour l'axe x à la place de la colonne '
#     - Une courbe avec les valeurs de 1948 de couleur 'red'
#     - Une courbe avec les valeurs de 1949 de couleur 'blue'
# - Afficher les courbes.

# %%
unrate['MONTH'] = unrate['DATE'].dt.month

plt.figure(figsize=(6,3), facecolor="white")

plt.plot(unrate['MONTH'][:12], unrate['UNRATE'][:12], color='tab:red')
plt.plot(unrate['MONTH'][:12], unrate['UNRATE'][12:24], color='tab:blue')

plt.xlabel("Mois")
plt.ylabel("Taux de hômage(%)")

plt.show()
plt.close()

# %% [markdown]
# ## Ajouter plus de courbes
#
# - Définir la zone d'affichage du graphique à 10 pouces de large et 6 pouces de haut.
# - Générer les courbes suivantes sur le même graphique:
#     - 1948: courbe en rouge ' red
#     - 1949: courbe en bleu ' blue
#     - 1950: courbe en vert 'green'
#     - 1951: courbe en orange 'orange'
#     - 1952: courbe en noir 'black'
# - Afficher les courbes.
#
# (Une boucle for peut être utile.)

# %%
plt.figure(figsize=(10,6), facecolor="white")

for i, c in zip(range(5), ["tab:red","tab:blue","tab:green","tab:orange","black"]):

    plt.plot(unrate['MONTH'][:12], unrate['UNRATE'][12*i:12*(i+1)], color=c, label=str(1948+i))

plt.xlabel("Mois")
plt.ylabel("Taux de chômage(%)")
plt.title("Evolution du taux de chômage de 1948 à 1952")

plt.legend(loc="upper left")
plt.show()
plt.close()

# %%
plt.figure(figsize=(10,6),facecolor="white") 

for i, c in zip(range(5), ["tab:red","tab:blue","tab:green","tab:orange","black"]):
    
    plt.plot(unrate['DATE'][12*i:13*(i+1)], unrate['UNRATE'][12*i:13*(i+1)], color=c, label=str(1948+i))

plt.xlabel("Date")
plt.ylabel("Taux de chômage (%)")
plt.title("Evolution du taux de chômage de 1948 à 1952")

plt.legend()
plt.show()
plt.close()
